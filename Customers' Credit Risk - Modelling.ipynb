# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Loading the Data and Selecting the Features

# %% [markdown]
# ### Import Data

# %%
loan_data_inputs_train = pd.read_csv('loan_data_inputs_train2.csv', index_col = 0)
loan_data_targets_train = pd.read_csv('loan_data_targets_train2.csv', index_col = 0)
loan_data_inputs_test = pd.read_csv('loan_data_inputs_test2.csv', index_col = 0)
loan_data_targets_test = pd.read_csv('loan_data_targets_test2.csv', index_col = 0)

# %% [markdown]
# ### Explore Data

# %%
pd.options.display.max_rows = None
# Sets the pandas dataframe options to display all columns/ rows.

# %%
loan_data_inputs_train.head()
# Out:
#         Unnamed: 0.1        id  member_id  loan_amnt  funded_amnt  \
# 427211        427211  12796369   14818505      24000        24000
# 206088        206088   1439740    1691948      10000        10000
# 136020        136020   5214749    6556909      20425        20425
# 412305        412305  13827698   15890016      17200        17200
# 36159          36159    422455     496525       8400         8400
#
#         funded_amnt_inv        term  int_rate  installment grade  ...  \
# 427211          24000.0   36 months      8.90       762.08     A  ...
# 206088          10000.0   36 months     14.33       343.39     C  ...
# 136020          20425.0   36 months      8.90       648.56     A  ...
# 412305          17200.0   36 months     16.59       609.73     D  ...
# 36159            7450.0   36 months     12.84       282.40     C  ...
#
#        dti:21.7-22.4 dti:22.4-35 dti:>35 mths_since_last_record:Missing  \
# 427211             1           0       0                              1
# 206088             0           0       0                              1
# 136020             0           0       0                              1
# 412305             0           0       0                              1
# 36159              0           1       0                              1
#
#         mths_since_last_record:0-2 mths_since_last_record:3-20  \
# 427211                           0                           0
# 206088                           0                           0
# 136020                           0                           0
# 412305                           0                           0
# 36159                            0                           0
#
#        mths_since_last_record:21-31 mths_since_last_record:32-80  \
# 427211                            0                            0
# 206088                            0                            0
# 136020                            0                            0
# 412305                            0                            0
# 36159                             0                            0
#
#        mths_since_last_record:81-86 mths_since_last_record:>86
# 427211                            0                          0
# 206088                            0                          0
# 136020                            0                          0
# 412305                            0                          0
# 36159                             0                          0
#
# [5 rows x 324 columns]

# %%
loan_data_inputs_train.shape
# Out:
# (373028, 324)

# %%
loan_data_targets_train.shape
# Out:
# (373028, 1)

# %%
loan_data_inputs_test.shape
# Out:
# (93257, 324)

# %%
loan_data_targets_test.shape
# Out:
# (93257, 1)

# %%
loan_data_targets_train.head()
# Out:
#         good_bad
# 427211         1
# 206088         1
# 136020         1
# 412305         0
# 36159          0

# %%
loan_data_targets_test.head()
# Out:
#         good_bad
# 362514         1
# 288564         1
# 213591         1
# 263083         1
# 165001         1

# %% [markdown]
# ### Selecting the Features

# %%
# Here we select a limited set of input variables in a new dataframe.
inputs_train_with_ref_cat = loan_data_inputs_train.reindex(columns = ['grade:A',
'grade:B',
'grade:C',
'grade:D',
'grade:E',
'grade:F',
'grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'home_ownership:OWN',
'home_ownership:MORTGAGE',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'addr_state:NM_VA',
'addr_state:NY',
'addr_state:OK_TN_MO_LA_MD_NC',
'addr_state:CA',
'addr_state:UT_KY_AZ_NJ',
'addr_state:AR_MI_PA_OH_MN',
'addr_state:RI_MA_DE_SD_IN',
'addr_state:GA_WA_OR',
'addr_state:WI_MT',
'addr_state:TX',
'addr_state:IL_CT',
'addr_state:KS_SC_CO_VT_AK_MS',
'addr_state:WV_NH_WY_DC_ME_ID',
'verification_status:Not Verified',
'verification_status:Source Verified',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'purpose:credit_card',
'purpose:debt_consolidation',
'purpose:oth__med__vacation',
'purpose:major_purch__car__home_impr',
'initial_list_status:f',
'initial_list_status:w',
'term:36',
'term:60',
'emp_length:0',
'emp_length:1',
'emp_length:2-4',
'emp_length:5-6',
'emp_length:7-9',
'emp_length:10',
'mths_since_issue_d:<38',
'mths_since_issue_d:38-39',
'mths_since_issue_d:40-41',
'mths_since_issue_d:42-48',
'mths_since_issue_d:49-52',
'mths_since_issue_d:53-64',
'mths_since_issue_d:65-84',
'mths_since_issue_d:>84',
'int_rate:<9.548',
'int_rate:9.548-12.025',
'int_rate:12.025-15.74',
'int_rate:15.74-20.281',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'mths_since_earliest_cr_line:141-164',
'mths_since_earliest_cr_line:165-247',
'mths_since_earliest_cr_line:248-270',
'mths_since_earliest_cr_line:271-352',
'mths_since_earliest_cr_line:>352',
'delinq_2yrs:0',
'delinq_2yrs:1-3',
'delinq_2yrs:>=4',
'inq_last_6mths:0',
'inq_last_6mths:1-2',
'inq_last_6mths:3-6',
'inq_last_6mths:>6',
'open_acc:0',
'open_acc:1-3',
'open_acc:4-12',
'open_acc:13-17',
'open_acc:18-22',
'open_acc:23-25',
'open_acc:26-30',
'open_acc:>=31',
'pub_rec:0-2',
'pub_rec:3-4',
'pub_rec:>=5',
'total_acc:<=27',
'total_acc:28-51',
'total_acc:>=52',
'acc_now_delinq:0',
'acc_now_delinq:>=1',
'total_rev_hi_lim:<=5K',
'total_rev_hi_lim:5K-10K',
'total_rev_hi_lim:10K-20K',
'total_rev_hi_lim:20K-30K',
'total_rev_hi_lim:30K-40K',
'total_rev_hi_lim:40K-55K',
'total_rev_hi_lim:55K-95K',
'total_rev_hi_lim:>95K',
'annual_inc:<20K',
'annual_inc:20K-30K',
'annual_inc:30K-40K',
'annual_inc:40K-50K',
'annual_inc:50K-60K',
'annual_inc:60K-70K',
'annual_inc:70K-80K',
'annual_inc:80K-90K',
'annual_inc:90K-100K',
'annual_inc:100K-120K',
'annual_inc:120K-140K',
'annual_inc:>140K',
'dti:<=1.4',
'dti:1.4-3.5',
'dti:3.5-7.7',
'dti:7.7-10.5',
'dti:10.5-16.1',
'dti:16.1-20.3',
'dti:20.3-21.7',
'dti:21.7-22.4',
'dti:22.4-35',
'dti:>35',
#'mths_since_last_delinq:Missing',
'mths_since_last_delinq:0-3',
'mths_since_last_delinq:4-30',
'mths_since_last_delinq:31-56',
'mths_since_last_delinq:>=57',
#'mths_since_last_record:Missing',
'mths_since_last_record:0-2',
'mths_since_last_record:3-20',
'mths_since_last_record:21-31',
'mths_since_last_record:32-80',
'mths_since_last_record:81-86',
'mths_since_last_record:>86'
])

# %%
inputs_train_with_ref_cat.columns
# Out:
# Index(['grade:A', 'grade:B', 'grade:C', 'grade:D', 'grade:E', 'grade:F',
#        'grade:G', 'home_ownership:RENT_OTHER_NONE_ANY', 'home_ownership:OWN',
#        'home_ownership:MORTGAGE',
#        ...
#        'mths_since_last_delinq:0-3', 'mths_since_last_delinq:4-30',
#        'mths_since_last_delinq:31-56', 'mths_since_last_delinq:>=57',
#        'mths_since_last_record:0-2', 'mths_since_last_record:3-20',
#        'mths_since_last_record:21-31', 'mths_since_last_record:32-80',
#        'mths_since_last_record:81-86', 'mths_since_last_record:>86'],
#       dtype='object', length=124)

# %%
# Here we store the names of the reference category dummy variables in a list.
ref_categories = ['grade:G',
'home_ownership:RENT_OTHER_NONE_ANY', 
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'initial_list_status:f',
'term:60',
'emp_length:0',
'mths_since_issue_d:>84',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'delinq_2yrs:>=4',
'inq_last_6mths:>6',
'open_acc:0',
'pub_rec:0-2',
'total_acc:<=27',
'acc_now_delinq:0',
'total_rev_hi_lim:<=5K',
'annual_inc:<20K',
'dti:>35',
'mths_since_last_delinq:0-3',
'mths_since_last_record:0-2']

# %%
inputs_train = inputs_train_with_ref_cat.drop(ref_categories, axis = 1)
# From the dataframe with input variables, we drop the variables with variable names in the list with reference categories. 
inputs_train.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 427211        1        0        0        0        0        0
# 206088        0        0        1        0        0        0
# 136020        1        0        0        0        0        0
# 412305        0        0        0        1        0        0
# 36159         0        0        1        0        0        0
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 427211                   0                        1                 0
# 206088                   0                        1                 0
# 136020                   0                        1                 0
# 412305                   0                        0                 0
# 36159                    0                        1                 0
#
#         addr_state:NY  ...  dti:21.7-22.4  dti:22.4-35  \
# 427211              0  ...              1            0
# 206088              0  ...              0            0
# 136020              0  ...              0            0
# 412305              0  ...              0            0
# 36159               0  ...              0            1
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 427211                            0                             0
# 206088                            1                             0
# 136020                            0                             1
# 412305                            1                             0
# 36159                             0                             0
#
#         mths_since_last_delinq:>=57  mths_since_last_record:3-20  \
# 427211                            0                            0
# 206088                            0                            0
# 136020                            0                            0
# 412305                            0                            0
# 36159                             0                            0
#
#         mths_since_last_record:21-31  mths_since_last_record:32-80  \
# 427211                             0                             0
# 206088                             0                             0
# 136020                             0                             0
# 412305                             0                             0
# 36159                              0                             0
#
#         mths_since_last_record:81-86  mths_since_last_record:>86
# 427211                             0                           0
# 206088                             0                           0
# 136020                             0                           0
# 412305                             0                           0
# 36159                              0                           0
#
# [5 rows x 102 columns]

# %%
pd.options.display.max_rows = None
# Sets the pandas dataframe options to display all columns/ rows.

# %%
inputs_train.isnull().sum()
# Out:
# grade:A                                0
# grade:B                                0
# grade:C                                0
# grade:D                                0
# grade:E                                0
# grade:F                                0
# home_ownership:OWN                     0
# home_ownership:MORTGAGE                0
# addr_state:NM_VA                       0
# addr_state:NY                          0
# addr_state:OK_TN_MO_LA_MD_NC           0
# addr_state:CA                          0
# addr_state:UT_KY_AZ_NJ                 0
# addr_state:AR_MI_PA_OH_MN              0
# addr_state:RI_MA_DE_SD_IN              0
# addr_state:GA_WA_OR                    0
# addr_state:WI_MT                       0
# addr_state:TX                          0
# addr_state:IL_CT                       0
# addr_state:KS_SC_CO_VT_AK_MS           0
# addr_state:WV_NH_WY_DC_ME_ID           0
# verification_status:Not Verified       0
# verification_status:Source Verified    0
# purpose:credit_card                    0
# purpose:debt_consolidation             0
# purpose:oth__med__vacation             0
# purpose:major_purch__car__home_impr    0
# initial_list_status:w                  0
# term:36                                0
# emp_length:1                           0
# emp_length:2-4                         0
# emp_length:5-6                         0
# emp_length:7-9                         0
# emp_length:10                          0
# mths_since_issue_d:<38                 0
# mths_since_issue_d:38-39               0
# mths_since_issue_d:40-41               0
# mths_since_issue_d:42-48               0
# mths_since_issue_d:49-52               0
# mths_since_issue_d:53-64               0
# mths_since_issue_d:65-84               0
# int_rate:<9.548                        0
# int_rate:9.548-12.025                  0
# int_rate:12.025-15.74                  0
# int_rate:15.74-20.281                  0
# mths_since_earliest_cr_line:141-164    0
# mths_since_earliest_cr_line:165-247    0
# mths_since_earliest_cr_line:248-270    0
# mths_since_earliest_cr_line:271-352    0
# mths_since_earliest_cr_line:>352       0
# delinq_2yrs:0                          0
# delinq_2yrs:1-3                        0
# inq_last_6mths:0                       0
# inq_last_6mths:1-2                     0
# inq_last_6mths:3-6                     0
# open_acc:1-3                           0
# open_acc:4-12                          0
# open_acc:13-17                         0
# open_acc:18-22                         0
# open_acc:23-25                         0
# open_acc:26-30                         0
# open_acc:>=31                          0
# pub_rec:3-4                            0
# pub_rec:>=5                            0
# total_acc:28-51                        0
# total_acc:>=52                         0
# acc_now_delinq:>=1                     0
# total_rev_hi_lim:5K-10K                0
# total_rev_hi_lim:10K-20K               0
# total_rev_hi_lim:20K-30K               0
# total_rev_hi_lim:30K-40K               0
# total_rev_hi_lim:40K-55K               0
# total_rev_hi_lim:55K-95K               0
# total_rev_hi_lim:>95K                  0
# annual_inc:20K-30K                     0
# annual_inc:30K-40K                     0
# annual_inc:40K-50K                     0
# annual_inc:50K-60K                     0
# annual_inc:60K-70K                     0
# annual_inc:70K-80K                     0
# annual_inc:80K-90K                     0
# annual_inc:90K-100K                    0
# annual_inc:100K-120K                   0
# annual_inc:120K-140K                   0
# annual_inc:>140K                       0
# dti:<=1.4                              0
# dti:1.4-3.5                            0
# dti:3.5-7.7                            0
# dti:7.7-10.5                           0
# dti:10.5-16.1                          0
# dti:16.1-20.3                          0
# dti:20.3-21.7                          0
# dti:21.7-22.4                          0
# dti:22.4-35                            0
# mths_since_last_delinq:4-30            0
# mths_since_last_delinq:31-56           0
# mths_since_last_delinq:>=57            0
# mths_since_last_record:3-20            0
# mths_since_last_record:21-31           0
# mths_since_last_record:32-80           0
# mths_since_last_record:81-86           0
# mths_since_last_record:>86             0
# dtype: int64

# %% [markdown]
# # PD Model Estimation

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
reg = LogisticRegression()
# We create an instance of an object from the 'LogisticRegression' class.

# %%
reg.fit(inputs_train, loan_data_targets_train)
# Estimates the coefficients of the object from the 'LogisticRegression' class
# with inputs (independent variables) contained in the first dataframe
# and targets (dependent variables) contained in the second dataframe.
# Out:
# C:\Users\USR\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\USR\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
reg.intercept_
# Displays the intercept contain in the estimated ("fitted") object from the 'LogisticRegression' class.
# Out:
# array([-1.09165639])

# %%
reg.coef_
# Displays the coefficients contained in the estimated ("fitted") object from the 'LogisticRegression' class.
# Out:
# array([[ 1.17770762,  0.93102908,  0.73140486,  0.53849558,  0.35140798,
#          0.16138252,  0.09182383,  0.10614611,  0.03853973,  0.0604108 ,
#          0.06045966,  0.06420698,  0.07920694,  0.13813794,  0.09980552,
#          0.18552349,  0.24436594,  0.22564866,  0.26492806,  0.3213369 ,
#          0.52073143,  0.08376557, -0.01129538,  0.30699327,  0.20314798,
#          0.216342  ,  0.27163796,  0.05308755,  0.07816616,  0.10126738,
#          0.12815939,  0.09360788,  0.06231482,  0.12432899,  1.10719392,
#          0.90855985,  0.80811328,  0.60436839,  0.44184182,  0.19593336,
#         -0.03996936,  0.84947634,  0.52856994,  0.28240288,  0.09706559,
#          0.06215649,  0.04256091,  0.08413174,  0.12514948,  0.13037864,
#          0.10248789,  0.04562078,  0.69395988,  0.55023352,  0.33982344,
#          0.01892662, -0.0739949 , -0.10041778, -0.11679107, -0.12375245,
#         -0.07729868, -0.17539935,  0.12146057,  0.16415317, -0.02127768,
#          0.02217183,  0.13998586,  0.03921888,  0.00720543,  0.00510227,
#          0.01851024,  0.03991457,  0.06632127,  0.20848207, -0.05792433,
#          0.00915813,  0.10764331,  0.17660317,  0.25306487,  0.32711173,
#          0.40244608,  0.42153502,  0.4986334 ,  0.58319178,  0.51390694,
#          0.19490329,  0.32894267,  0.35985252,  0.30059671,  0.22504069,
#          0.12700792,  0.11742476,  0.08264377,  0.04212617,  0.07963541,
#          0.08064014,  0.03192637,  0.09639876,  0.02145564,  0.18411655,
#         -0.14948394, -0.084607  ]])

# %%
feature_name = inputs_train.columns.values
# Stores the names of the columns of a dataframe in a variable.

# %%
summary_table = pd.DataFrame(columns = ['Feature name'], data = feature_name)
# Creates a dataframe with a column titled 'Feature name' and row values contained in the 'feature_name' variable.
summary_table['Coefficients'] = np.transpose(reg.coef_)
# Creates a new column in the dataframe, called 'Coefficients',
# with row values the transposed coefficients from the 'LogisticRegression' object.
summary_table.index = summary_table.index + 1
# Increases the index of every row of the dataframe with 1.
summary_table.loc[0] = ['Intercept', reg.intercept_[0]]
# Assigns values of the row with index 0 of the dataframe.
summary_table = summary_table.sort_index()
# Sorts the dataframe by index.
summary_table
# Out:
#                             Feature name  Coefficients
# 0                              Intercept     -1.091656
# 1                                grade:A      1.177708
# 2                                grade:B      0.931029
# 3                                grade:C      0.731405
# 4                                grade:D      0.538496
# 5                                grade:E      0.351408
# 6                                grade:F      0.161383
# 7                     home_ownership:OWN      0.091824
# 8                home_ownership:MORTGAGE      0.106146
# 9                       addr_state:NM_VA      0.038540
# 10                         addr_state:NY      0.060411
# 11          addr_state:OK_TN_MO_LA_MD_NC      0.060460
# 12                         addr_state:CA      0.064207
# 13                addr_state:UT_KY_AZ_NJ      0.079207
# 14             addr_state:AR_MI_PA_OH_MN      0.138138
# 15             addr_state:RI_MA_DE_SD_IN      0.099806
# 16                   addr_state:GA_WA_OR      0.185523
# 17                      addr_state:WI_MT      0.244366
# 18                         addr_state:TX      0.225649
# 19                      addr_state:IL_CT      0.264928
# 20          addr_state:KS_SC_CO_VT_AK_MS      0.321337
# 21          addr_state:WV_NH_WY_DC_ME_ID      0.520731
# 22      verification_status:Not Verified      0.083766
# 23   verification_status:Source Verified     -0.011295
# 24                   purpose:credit_card      0.306993
# 25            purpose:debt_consolidation      0.203148
# 26            purpose:oth__med__vacation      0.216342
# 27   purpose:major_purch__car__home_impr      0.271638
# 28                 initial_list_status:w      0.053088
# 29                               term:36      0.078166
# 30                          emp_length:1      0.101267
# 31                        emp_length:2-4      0.128159
# 32                        emp_length:5-6      0.093608
# 33                        emp_length:7-9      0.062315
# 34                         emp_length:10      0.124329
# 35                mths_since_issue_d:<38      1.107194
# 36              mths_since_issue_d:38-39      0.908560
# 37              mths_since_issue_d:40-41      0.808113
# 38              mths_since_issue_d:42-48      0.604368
# 39              mths_since_issue_d:49-52      0.441842
# 40              mths_since_issue_d:53-64      0.195933
# 41              mths_since_issue_d:65-84     -0.039969
# 42                       int_rate:<9.548      0.849476
# 43                 int_rate:9.548-12.025      0.528570
# 44                 int_rate:12.025-15.74      0.282403
# 45                 int_rate:15.74-20.281      0.097066
# 46   mths_since_earliest_cr_line:141-164      0.062156
# 47   mths_since_earliest_cr_line:165-247      0.042561
# 48   mths_since_earliest_cr_line:248-270      0.084132
# 49   mths_since_earliest_cr_line:271-352      0.125149
# 50      mths_since_earliest_cr_line:>352      0.130379
# 51                         delinq_2yrs:0      0.102488
# 52                       delinq_2yrs:1-3      0.045621
# 53                      inq_last_6mths:0      0.693960
# 54                    inq_last_6mths:1-2      0.550234
# 55                    inq_last_6mths:3-6      0.339823
# 56                          open_acc:1-3      0.018927
# 57                         open_acc:4-12     -0.073995
# 58                        open_acc:13-17     -0.100418
# 59                        open_acc:18-22     -0.116791
# 60                        open_acc:23-25     -0.123752
# 61                        open_acc:26-30     -0.077299
# 62                         open_acc:>=31     -0.175399
# 63                           pub_rec:3-4      0.121461
# 64                           pub_rec:>=5      0.164153
# 65                       total_acc:28-51     -0.021278
# 66                        total_acc:>=52      0.022172
# 67                    acc_now_delinq:>=1      0.139986
# 68               total_rev_hi_lim:5K-10K      0.039219
# 69              total_rev_hi_lim:10K-20K      0.007205
# 70              total_rev_hi_lim:20K-30K      0.005102
# 71              total_rev_hi_lim:30K-40K      0.018510
# 72              total_rev_hi_lim:40K-55K      0.039915
# 73              total_rev_hi_lim:55K-95K      0.066321
# 74                 total_rev_hi_lim:>95K      0.208482
# 75                    annual_inc:20K-30K     -0.057924
# 76                    annual_inc:30K-40K      0.009158
# 77                    annual_inc:40K-50K      0.107643
# 78                    annual_inc:50K-60K      0.176603
# 79                    annual_inc:60K-70K      0.253065
# 80                    annual_inc:70K-80K      0.327112
# 81                    annual_inc:80K-90K      0.402446
# 82                   annual_inc:90K-100K      0.421535
# 83                  annual_inc:100K-120K      0.498633
# 84                  annual_inc:120K-140K      0.583192
# 85                      annual_inc:>140K      0.513907
# 86                             dti:<=1.4      0.194903
# 87                           dti:1.4-3.5      0.328943
# 88                           dti:3.5-7.7      0.359853
# 89                          dti:7.7-10.5      0.300597
# 90                         dti:10.5-16.1      0.225041
# 91                         dti:16.1-20.3      0.127008
# 92                         dti:20.3-21.7      0.117425
# 93                         dti:21.7-22.4      0.082644
# 94                           dti:22.4-35      0.042126
# 95           mths_since_last_delinq:4-30      0.079635
# 96          mths_since_last_delinq:31-56      0.080640
# 97           mths_since_last_delinq:>=57      0.031926
# 98           mths_since_last_record:3-20      0.096399
# 99          mths_since_last_record:21-31      0.021456
# 100         mths_since_last_record:32-80      0.184117
# 101         mths_since_last_record:81-86     -0.149484
# 102           mths_since_last_record:>86     -0.084607

# %% [markdown]
# ## Build a Logistic Regression Model with P-Values

# %%
# P values for sklearn logistic regression.

# Class to display p-values for logistic regression in sklearn.

from sklearn import linear_model
import scipy.stats as stat

class LogisticRegression_with_p_values:
    
    def __init__(self,*args,**kwargs):#,**kwargs):
        self.model = linear_model.LogisticRegression(*args,**kwargs)#,**args)

    def fit(self,X,y):
        self.model.fit(X,y)
        
        #### Get p-values for the fitted model ####
        denom = (2.0 * (1.0 + np.cosh(self.model.decision_function(X))))
        denom = np.tile(denom,(X.shape[1],1)).T
        F_ij = np.dot((X / denom).T,X) ## Fisher Information Matrix
        Cramer_Rao = np.linalg.inv(F_ij) ## Inverse Information Matrix
        sigma_estimates = np.sqrt(np.diagonal(Cramer_Rao))
        z_scores = self.model.coef_[0] / sigma_estimates # z-score for eaach model coefficient
        p_values = [stat.norm.sf(abs(x)) * 2 for x in z_scores] ### two tailed test for p-values
        
        self.coef_ = self.model.coef_
        self.intercept_ = self.model.intercept_
        self.p_values = p_values

# %%
reg = LogisticRegression_with_p_values()
# We create an instance of an object from the newly created 'LogisticRegression_with_p_values()' class.

# %%
reg.fit(inputs_train, loan_data_targets_train)
# Estimates the coefficients of the object from the 'LogisticRegression' class
# with inputs (independent variables) contained in the first dataframe
# and targets (dependent variables) contained in the second dataframe.
# Out:
# C:\Users\USR\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\USR\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Same as above.
summary_table = pd.DataFrame(columns = ['Feature name'], data = feature_name)
summary_table['Coefficients'] = np.transpose(reg.coef_)
summary_table.index = summary_table.index + 1
summary_table.loc[0] = ['Intercept', reg.intercept_[0]]
summary_table = summary_table.sort_index()
summary_table
# Out:
#                             Feature name  Coefficients
# 0                              Intercept     -1.091656
# 1                                grade:A      1.177708
# 2                                grade:B      0.931029
# 3                                grade:C      0.731405
# 4                                grade:D      0.538496
# 5                                grade:E      0.351408
# 6                                grade:F      0.161383
# 7                     home_ownership:OWN      0.091824
# 8                home_ownership:MORTGAGE      0.106146
# 9                       addr_state:NM_VA      0.038540
# 10                         addr_state:NY      0.060411
# 11          addr_state:OK_TN_MO_LA_MD_NC      0.060460
# 12                         addr_state:CA      0.064207
# 13                addr_state:UT_KY_AZ_NJ      0.079207
# 14             addr_state:AR_MI_PA_OH_MN      0.138138
# 15             addr_state:RI_MA_DE_SD_IN      0.099806
# 16                   addr_state:GA_WA_OR      0.185523
# 17                      addr_state:WI_MT      0.244366
# 18                         addr_state:TX      0.225649
# 19                      addr_state:IL_CT      0.264928
# 20          addr_state:KS_SC_CO_VT_AK_MS      0.321337
# 21          addr_state:WV_NH_WY_DC_ME_ID      0.520731
# 22      verification_status:Not Verified      0.083766
# 23   verification_status:Source Verified     -0.011295
# 24                   purpose:credit_card      0.306993
# 25            purpose:debt_consolidation      0.203148
# 26            purpose:oth__med__vacation      0.216342
# 27   purpose:major_purch__car__home_impr      0.271638
# 28                 initial_list_status:w      0.053088
# 29                               term:36      0.078166
# 30                          emp_length:1      0.101267
# 31                        emp_length:2-4      0.128159
# 32                        emp_length:5-6      0.093608
# 33                        emp_length:7-9      0.062315
# 34                         emp_length:10      0.124329
# 35                mths_since_issue_d:<38      1.107194
# 36              mths_since_issue_d:38-39      0.908560
# 37              mths_since_issue_d:40-41      0.808113
# 38              mths_since_issue_d:42-48      0.604368
# 39              mths_since_issue_d:49-52      0.441842
# 40              mths_since_issue_d:53-64      0.195933
# 41              mths_since_issue_d:65-84     -0.039969
# 42                       int_rate:<9.548      0.849476
# 43                 int_rate:9.548-12.025      0.528570
# 44                 int_rate:12.025-15.74      0.282403
# 45                 int_rate:15.74-20.281      0.097066
# 46   mths_since_earliest_cr_line:141-164      0.062156
# 47   mths_since_earliest_cr_line:165-247      0.042561
# 48   mths_since_earliest_cr_line:248-270      0.084132
# 49   mths_since_earliest_cr_line:271-352      0.125149
# 50      mths_since_earliest_cr_line:>352      0.130379
# 51                         delinq_2yrs:0      0.102488
# 52                       delinq_2yrs:1-3      0.045621
# 53                      inq_last_6mths:0      0.693960
# 54                    inq_last_6mths:1-2      0.550234
# 55                    inq_last_6mths:3-6      0.339823
# 56                          open_acc:1-3      0.018927
# 57                         open_acc:4-12     -0.073995
# 58                        open_acc:13-17     -0.100418
# 59                        open_acc:18-22     -0.116791
# 60                        open_acc:23-25     -0.123752
# 61                        open_acc:26-30     -0.077299
# 62                         open_acc:>=31     -0.175399
# 63                           pub_rec:3-4      0.121461
# 64                           pub_rec:>=5      0.164153
# 65                       total_acc:28-51     -0.021278
# 66                        total_acc:>=52      0.022172
# 67                    acc_now_delinq:>=1      0.139986
# 68               total_rev_hi_lim:5K-10K      0.039219
# 69              total_rev_hi_lim:10K-20K      0.007205
# 70              total_rev_hi_lim:20K-30K      0.005102
# 71              total_rev_hi_lim:30K-40K      0.018510
# 72              total_rev_hi_lim:40K-55K      0.039915
# 73              total_rev_hi_lim:55K-95K      0.066321
# 74                 total_rev_hi_lim:>95K      0.208482
# 75                    annual_inc:20K-30K     -0.057924
# 76                    annual_inc:30K-40K      0.009158
# 77                    annual_inc:40K-50K      0.107643
# 78                    annual_inc:50K-60K      0.176603
# 79                    annual_inc:60K-70K      0.253065
# 80                    annual_inc:70K-80K      0.327112
# 81                    annual_inc:80K-90K      0.402446
# 82                   annual_inc:90K-100K      0.421535
# 83                  annual_inc:100K-120K      0.498633
# 84                  annual_inc:120K-140K      0.583192
# 85                      annual_inc:>140K      0.513907
# 86                             dti:<=1.4      0.194903
# 87                           dti:1.4-3.5      0.328943
# 88                           dti:3.5-7.7      0.359853
# 89                          dti:7.7-10.5      0.300597
# 90                         dti:10.5-16.1      0.225041
# 91                         dti:16.1-20.3      0.127008
# 92                         dti:20.3-21.7      0.117425
# 93                         dti:21.7-22.4      0.082644
# 94                           dti:22.4-35      0.042126
# 95           mths_since_last_delinq:4-30      0.079635
# 96          mths_since_last_delinq:31-56      0.080640
# 97           mths_since_last_delinq:>=57      0.031926
# 98           mths_since_last_record:3-20      0.096399
# 99          mths_since_last_record:21-31      0.021456
# 100         mths_since_last_record:32-80      0.184117
# 101         mths_since_last_record:81-86     -0.149484
# 102           mths_since_last_record:>86     -0.084607

# %%
# This is a list.
p_values = reg.p_values
# We take the result of the newly added method 'p_values' and store it in a variable 'p_values'.

# %%
# Add the intercept for completeness.
p_values = np.append("-", np.array(p_values))
# We add the value 'NaN' in the beginning of the variable with p-values.

# %%
summary_table['p_values'] = p_values
# In the 'summary_table' dataframe, we add a new column, called 'p_values', containing the values from the 'p_values' variable.

# %%
summary_table
# Out:
#                             Feature name  Coefficients  \
# 0                              Intercept     -1.091656
# 1                                grade:A      1.177708
# 2                                grade:B      0.931029
# 3                                grade:C      0.731405
# 4                                grade:D      0.538496
# 5                                grade:E      0.351408
# 6                                grade:F      0.161383
# 7                     home_ownership:OWN      0.091824
# 8                home_ownership:MORTGAGE      0.106146
# 9                       addr_state:NM_VA      0.038540
# 10                         addr_state:NY      0.060411
# 11          addr_state:OK_TN_MO_LA_MD_NC      0.060460
# 12                         addr_state:CA      0.064207
# 13                addr_state:UT_KY_AZ_NJ      0.079207
# 14             addr_state:AR_MI_PA_OH_MN      0.138138
# 15             addr_state:RI_MA_DE_SD_IN      0.099806
# 16                   addr_state:GA_WA_OR      0.185523
# 17                      addr_state:WI_MT      0.244366
# 18                         addr_state:TX      0.225649
# 19                      addr_state:IL_CT      0.264928
# 20          addr_state:KS_SC_CO_VT_AK_MS      0.321337
# 21          addr_state:WV_NH_WY_DC_ME_ID      0.520731
# 22      verification_status:Not Verified      0.083766
# 23   verification_status:Source Verified     -0.011295
# 24                   purpose:credit_card      0.306993
# 25            purpose:debt_consolidation      0.203148
# 26            purpose:oth__med__vacation      0.216342
# 27   purpose:major_purch__car__home_impr      0.271638
# 28                 initial_list_status:w      0.053088
# 29                               term:36      0.078166
# 30                          emp_length:1      0.101267
# 31                        emp_length:2-4      0.128159
# 32                        emp_length:5-6      0.093608
# 33                        emp_length:7-9      0.062315
# 34                         emp_length:10      0.124329
# 35                mths_since_issue_d:<38      1.107194
# 36              mths_since_issue_d:38-39      0.908560
# 37              mths_since_issue_d:40-41      0.808113
# 38              mths_since_issue_d:42-48      0.604368
# 39              mths_since_issue_d:49-52      0.441842
# 40              mths_since_issue_d:53-64      0.195933
# 41              mths_since_issue_d:65-84     -0.039969
# 42                       int_rate:<9.548      0.849476
# 43                 int_rate:9.548-12.025      0.528570
# 44                 int_rate:12.025-15.74      0.282403
# 45                 int_rate:15.74-20.281      0.097066
# 46   mths_since_earliest_cr_line:141-164      0.062156
# 47   mths_since_earliest_cr_line:165-247      0.042561
# 48   mths_since_earliest_cr_line:248-270      0.084132
# 49   mths_since_earliest_cr_line:271-352      0.125149
# 50      mths_since_earliest_cr_line:>352      0.130379
# 51                         delinq_2yrs:0      0.102488
# 52                       delinq_2yrs:1-3      0.045621
# 53                      inq_last_6mths:0      0.693960
# 54                    inq_last_6mths:1-2      0.550234
# 55                    inq_last_6mths:3-6      0.339823
# 56                          open_acc:1-3      0.018927
# 57                         open_acc:4-12     -0.073995
# 58                        open_acc:13-17     -0.100418
# 59                        open_acc:18-22     -0.116791
# 60                        open_acc:23-25     -0.123752
# 61                        open_acc:26-30     -0.077299
# 62                         open_acc:>=31     -0.175399
# 63                           pub_rec:3-4      0.121461
# 64                           pub_rec:>=5      0.164153
# 65                       total_acc:28-51     -0.021278
# 66                        total_acc:>=52      0.022172
# 67                    acc_now_delinq:>=1      0.139986
# 68               total_rev_hi_lim:5K-10K      0.039219
# 69              total_rev_hi_lim:10K-20K      0.007205
# 70              total_rev_hi_lim:20K-30K      0.005102
# 71              total_rev_hi_lim:30K-40K      0.018510
# 72              total_rev_hi_lim:40K-55K      0.039915
# 73              total_rev_hi_lim:55K-95K      0.066321
# 74                 total_rev_hi_lim:>95K      0.208482
# 75                    annual_inc:20K-30K     -0.057924
# 76                    annual_inc:30K-40K      0.009158
# 77                    annual_inc:40K-50K      0.107643
# 78                    annual_inc:50K-60K      0.176603
# 79                    annual_inc:60K-70K      0.253065
# 80                    annual_inc:70K-80K      0.327112
# 81                    annual_inc:80K-90K      0.402446
# 82                   annual_inc:90K-100K      0.421535
# 83                  annual_inc:100K-120K      0.498633
# 84                  annual_inc:120K-140K      0.583192
# 85                      annual_inc:>140K      0.513907
# 86                             dti:<=1.4      0.194903
# 87                           dti:1.4-3.5      0.328943
# 88                           dti:3.5-7.7      0.359853
# 89                          dti:7.7-10.5      0.300597
# 90                         dti:10.5-16.1      0.225041
# 91                         dti:16.1-20.3      0.127008
# 92                         dti:20.3-21.7      0.117425
# 93                         dti:21.7-22.4      0.082644
# 94                           dti:22.4-35      0.042126
# 95           mths_since_last_delinq:4-30      0.079635
# 96          mths_since_last_delinq:31-56      0.080640
# 97           mths_since_last_delinq:>=57      0.031926
# 98           mths_since_last_record:3-20      0.096399
# 99          mths_since_last_record:21-31      0.021456
# 100         mths_since_last_record:32-80      0.184117
# 101         mths_since_last_record:81-86     -0.149484
# 102           mths_since_last_record:>86     -0.084607
#
#                     p_values
# 0                          -
# 1      9.814039381615674e-39
# 2      6.848662899697011e-53
# 3      2.055616923436629e-38
# 4      9.729232086705104e-24
# 5      2.352735210441817e-13
# 6      0.0012564797109232279
# 7      5.374061529865013e-06
# 8      6.337121655653045e-17
# 9           0.22946988054479
# 10      0.012878756870854515
# 11      0.009186000116937489
# 12     0.0025036149284035298
# 13      0.001502411559562071
# 14     9.456724243678422e-10
# 15     0.0008337502979757875
# 16     3.772611510525184e-12
# 17    2.8940567368154205e-07
# 18    4.2455910359303244e-18
# 19    1.3697595848702495e-19
# 20    2.2559485830184924e-25
# 21    1.2335604334425812e-22
# 22    1.1289068371247304e-08
# 23       0.40185344310536086
# 24     3.509336902553976e-27
# 25     7.936422652312616e-15
# 26     4.236924614247697e-12
# 27     4.617421304845631e-18
# 28    4.7852492774213404e-05
# 29     3.510028428047649e-08
# 30     9.565757144528128e-05
# 31    1.1492196912255895e-11
# 32     1.231815546182128e-05
# 33     0.0027387048507473187
# 34    1.5583497055814427e-11
# 35   1.4488971129390756e-186
# 36    3.092858270551524e-157
# 37   4.1606468234357515e-131
# 38     6.660307615996711e-94
# 39     7.209536001874565e-45
# 40    3.3356281564090604e-11
# 41       0.16341379700637826
# 42     6.319399124536984e-29
# 43     3.730107786069785e-32
# 44     1.850723426919602e-14
# 45     0.0008453238496996703
# 46      0.012801190629844288
# 47      0.036492498369315486
# 48     0.0015576308740409886
# 49     1.623553114094243e-07
# 50    1.4103752395066944e-06
# 51       0.06639429363442861
# 52        0.3936705396447049
# 53    1.2462766216536817e-09
# 54    1.4153697526772117e-06
# 55     0.0030281990433074476
# 56        0.9033075534054599
# 57        0.6248843334484548
# 58        0.5080214269349639
# 59        0.4446037996750509
# 60       0.43277058985065664
# 61        0.6359957129077581
# 62       0.32493013719712427
# 63        0.2001327452010856
# 64       0.39253938150220546
# 65       0.13408406568374598
# 66        0.5765217742009378
# 67       0.14576259407283595
# 68       0.11133001208937603
# 69        0.7628599925143779
# 70        0.8458597082502949
# 71         0.529789228260432
# 72       0.21469039831529002
# 73        0.0658360471995719
# 74    0.00022589217307507315
# 75       0.17693862600915355
# 76         0.824907430274739
# 77      0.009385742431997492
# 78    2.6424075866399595e-05
# 79     4.120094009919849e-09
# 80      9.93028569916286e-14
# 81     1.469609895994421e-18
# 82     5.792512733903851e-19
# 83    3.4259734487491636e-26
# 84     7.126483955144862e-28
# 85     3.134994945186576e-25
# 86      0.027400065001745848
# 87    1.1093107333859284e-05
# 88     3.578651612908224e-08
# 89    3.4139609878732773e-06
# 90    0.00033467250925368224
# 91      0.042824375230382204
# 92       0.07153379890103326
# 93       0.23082747831895123
# 94       0.49654886256500774
# 95     0.0006693856206391024
# 96    1.0201184948594517e-06
# 97       0.11101900517313282
# 98        0.3033389351545186
# 99        0.7851794671851966
# 100    4.290648067121818e-12
# 101     0.016535852062378995
# 102   0.00021951793221177752

# %%
# Hypothesis : Ho: They are not significantly different
#              H1: They are significantly different
           

# Decision: reject Ho if p-value < 0.05

# We are going to drop some features, the coefficients for all or almost all of the dummy variables for which,
# are statistically insignificant (ie, their p_value > 0.05).

# We do that by specifying another list of dummy variables as reference categories, and a list of variables to remove.
# Then, we are going to drop the two datasets from the original list of dummy variables.


# Therefore the Selected Variables
cat_variable = ['grade:A',
'grade:B',
'grade:C',
'grade:D',
'grade:E',
'grade:F',
'grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'home_ownership:OWN',
'home_ownership:MORTGAGE',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'addr_state:NM_VA',
'addr_state:NY',
'addr_state:OK_TN_MO_LA_MD_NC',
'addr_state:CA',
'addr_state:UT_KY_AZ_NJ',
'addr_state:AR_MI_PA_OH_MN',
'addr_state:RI_MA_DE_SD_IN',
'addr_state:GA_WA_OR',
'addr_state:WI_MT',
'addr_state:TX',
'addr_state:IL_CT',
'addr_state:KS_SC_CO_VT_AK_MS',
'addr_state:WV_NH_WY_DC_ME_ID',
'verification_status:Not Verified',
'verification_status:Source Verified',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'purpose:credit_card',
'purpose:debt_consolidation',
'purpose:oth__med__vacation',
'purpose:major_purch__car__home_impr',
'initial_list_status:f',
'initial_list_status:w',
'term:36',
'term:60',
'emp_length:0',
'emp_length:1',
'emp_length:2-4',
'emp_length:5-6',
'emp_length:7-9',
'emp_length:10',
'mths_since_issue_d:<38',
'mths_since_issue_d:38-39',
'mths_since_issue_d:40-41',
'mths_since_issue_d:42-48',
'mths_since_issue_d:49-52',
'mths_since_issue_d:53-64',
'mths_since_issue_d:65-84',
'mths_since_issue_d:>84',
'int_rate:<9.548',
'int_rate:9.548-12.025',
'int_rate:12.025-15.74',
'int_rate:15.74-20.281',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'mths_since_earliest_cr_line:141-164',
'mths_since_earliest_cr_line:165-247',
'mths_since_earliest_cr_line:248-270',
'mths_since_earliest_cr_line:271-352',
'mths_since_earliest_cr_line:>352',
'inq_last_6mths:0',
'inq_last_6mths:1-2',
'inq_last_6mths:3-6',
'inq_last_6mths:>6',
'acc_now_delinq:0',
'acc_now_delinq:>=1',
'annual_inc:<20K',
'annual_inc:20K-30K',
'annual_inc:30K-40K',
'annual_inc:40K-50K',
'annual_inc:50K-60K',
'annual_inc:60K-70K',
'annual_inc:70K-80K',
'annual_inc:80K-90K',
'annual_inc:90K-100K',
'annual_inc:100K-120K',
'annual_inc:120K-140K',
'annual_inc:>140K',
'dti:<=1.4',
'dti:1.4-3.5',
'dti:3.5-7.7',
'dti:7.7-10.5',
'dti:10.5-16.1',
'dti:16.1-20.3',
'dti:20.3-21.7',
'dti:21.7-22.4',
'dti:22.4-35',
'dti:>35',
'mths_since_last_delinq:0-3',
'mths_since_last_delinq:4-30',
'mths_since_last_delinq:31-56',
'mths_since_last_delinq:>=57',
'mths_since_last_record:0-2',
'mths_since_last_record:3-20',
'mths_since_last_record:21-31',
'mths_since_last_record:32-80',
'mths_since_last_record:81-86',
'mths_since_last_record:>86',
]

inputs_train_with_ref_cat = loan_data_inputs_train.reindex(columns = cat_variable)

# %%
ref_categories = ['grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'initial_list_status:f',
'term:60',
'emp_length:0',
'mths_since_issue_d:>84',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'inq_last_6mths:>6',
'acc_now_delinq:0',
'annual_inc:<20K',
'dti:>35',
'mths_since_last_delinq:0-3',
'mths_since_last_record:0-2']

# %%
new_inputs_train = inputs_train_with_ref_cat.drop(ref_categories, axis = 1)
new_inputs_train.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 427211        1        0        0        0        0        0
# 206088        0        0        1        0        0        0
# 136020        1        0        0        0        0        0
# 412305        0        0        0        1        0        0
# 36159         0        0        1        0        0        0
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 427211                   0                        1                 0
# 206088                   0                        1                 0
# 136020                   0                        1                 0
# 412305                   0                        0                 0
# 36159                    0                        1                 0
#
#         addr_state:NY  ...  dti:21.7-22.4  dti:22.4-35  \
# 427211              0  ...              1            0
# 206088              0  ...              0            0
# 136020              0  ...              0            0
# 412305              0  ...              0            0
# 36159               0  ...              0            1
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 427211                            0                             0
# 206088                            1                             0
# 136020                            0                             1
# 412305                            1                             0
# 36159                             0                             0
#
#         mths_since_last_delinq:>=57  mths_since_last_record:3-20  \
# 427211                            0                            0
# 206088                            0                            0
# 136020                            0                            0
# 412305                            0                            0
# 36159                             0                            0
#
#         mths_since_last_record:21-31  mths_since_last_record:32-80  \
# 427211                             0                             0
# 206088                             0                             0
# 136020                             0                             0
# 412305                             0                             0
# 36159                              0                             0
#
#         mths_since_last_record:81-86  mths_since_last_record:>86
# 427211                             0                           0
# 206088                             0                           0
# 136020                             0                           0
# 412305                             0                           0
# 36159                              0                           0
#
# [5 rows x 82 columns]

# %%
# Here we run a new model the newly selected variables.

reg2 = LogisticRegression_with_p_values()
reg2.fit(new_inputs_train, loan_data_targets_train)
# Out:
# C:\Users\USR\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\USR\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
feature_name = new_inputs_train.columns.values

# %%
# Same as above.
summary_table = pd.DataFrame(columns = ['Feature name'], data = feature_name)
summary_table['Coefficients'] = np.transpose(reg2.coef_)
summary_table.index = summary_table.index + 1
summary_table.loc[0] = ['Intercept', reg2.intercept_[0]]
summary_table = summary_table.sort_index()
summary_table
# Out:
#                            Feature name  Coefficients
# 0                             Intercept     -1.047599
# 1                               grade:A      1.165892
# 2                               grade:B      0.909230
# 3                               grade:C      0.709035
# 4                               grade:D      0.516689
# 5                               grade:E      0.333389
# 6                               grade:F      0.141988
# 7                    home_ownership:OWN      0.092773
# 8               home_ownership:MORTGAGE      0.105344
# 9                      addr_state:NM_VA      0.036129
# 10                        addr_state:NY      0.055811
# 11         addr_state:OK_TN_MO_LA_MD_NC      0.058078
# 12                        addr_state:CA      0.063684
# 13               addr_state:UT_KY_AZ_NJ      0.077486
# 14            addr_state:AR_MI_PA_OH_MN      0.135918
# 15            addr_state:RI_MA_DE_SD_IN      0.098396
# 16                  addr_state:GA_WA_OR      0.184778
# 17                     addr_state:WI_MT      0.240971
# 18                        addr_state:TX      0.222359
# 19                     addr_state:IL_CT      0.262112
# 20         addr_state:KS_SC_CO_VT_AK_MS      0.319517
# 21         addr_state:WV_NH_WY_DC_ME_ID      0.520767
# 22     verification_status:Not Verified      0.081427
# 23  verification_status:Source Verified     -0.011579
# 24                  purpose:credit_card      0.301387
# 25           purpose:debt_consolidation      0.197625
# 26           purpose:oth__med__vacation      0.214027
# 27  purpose:major_purch__car__home_impr      0.266356
# 28                initial_list_status:w      0.053978
# 29                              term:36      0.076315
# 30                         emp_length:1      0.099682
# 31                       emp_length:2-4      0.127556
# 32                       emp_length:5-6      0.092862
# 33                       emp_length:7-9      0.062904
# 34                        emp_length:10      0.126634
# 35               mths_since_issue_d:<38      1.107287
# 36             mths_since_issue_d:38-39      0.903033
# 37             mths_since_issue_d:40-41      0.802033
# 38             mths_since_issue_d:42-48      0.599287
# 39             mths_since_issue_d:49-52      0.437741
# 40             mths_since_issue_d:53-64      0.191999
# 41             mths_since_issue_d:65-84     -0.047691
# 42                      int_rate:<9.548      0.856269
# 43                int_rate:9.548-12.025      0.539345
# 44                int_rate:12.025-15.74      0.292076
# 45                int_rate:15.74-20.281      0.105070
# 46  mths_since_earliest_cr_line:141-164      0.054506
# 47  mths_since_earliest_cr_line:165-247      0.034867
# 48  mths_since_earliest_cr_line:248-270      0.076319
# 49  mths_since_earliest_cr_line:271-352      0.118728
# 50     mths_since_earliest_cr_line:>352      0.126178
# 51                     inq_last_6mths:0      0.728722
# 52                   inq_last_6mths:1-2      0.582295
# 53                   inq_last_6mths:3-6      0.371090
# 54                   acc_now_delinq:>=1      0.080475
# 55                   annual_inc:20K-30K     -0.076128
# 56                   annual_inc:30K-40K     -0.012542
# 57                   annual_inc:40K-50K      0.082088
# 58                   annual_inc:50K-60K      0.149117
# 59                   annual_inc:60K-70K      0.223690
# 60                   annual_inc:70K-80K      0.297728
# 61                   annual_inc:80K-90K      0.373366
# 62                  annual_inc:90K-100K      0.392945
# 63                 annual_inc:100K-120K      0.471332
# 64                 annual_inc:120K-140K      0.563563
# 65                     annual_inc:>140K      0.497117
# 66                            dti:<=1.4      0.248337
# 67                          dti:1.4-3.5      0.367862
# 68                          dti:3.5-7.7      0.387017
# 69                         dti:7.7-10.5      0.322818
# 70                        dti:10.5-16.1      0.243819
# 71                        dti:16.1-20.3      0.142635
# 72                        dti:20.3-21.7      0.130564
# 73                        dti:21.7-22.4      0.095873
# 74                          dti:22.4-35      0.053202
# 75          mths_since_last_delinq:4-30      0.029882
# 76         mths_since_last_delinq:31-56      0.076022
# 77          mths_since_last_delinq:>=57      0.028950
# 78          mths_since_last_record:3-20      0.117086
# 79         mths_since_last_record:21-31      0.035485
# 80         mths_since_last_record:32-80      0.186250
# 81         mths_since_last_record:81-86     -0.148505
# 82           mths_since_last_record:>86     -0.084752

# %%
# We add the 'p_values' here, just as we did before.
p_values = reg2.p_values
p_values = np.append(np.nan,np.array(p_values))
summary_table['p_values'] = p_values
summary_table
# Here we get the results for our final PD model.
# Out:
#                            Feature name  Coefficients       p_values
# 0                             Intercept     -1.047599            NaN
# 1                               grade:A      1.165892   2.716800e-38
# 2                               grade:B      0.909230   4.630379e-51
# 3                               grade:C      0.709035   9.406165e-37
# 4                               grade:D      0.516689   1.829853e-22
# 5                               grade:E      0.333389   1.097572e-12
# 6                               grade:F      0.141988   3.548211e-03
# 7                    home_ownership:OWN      0.092773   4.111957e-06
# 8               home_ownership:MORTGAGE      0.105344   7.936424e-17
# 9                      addr_state:NM_VA      0.036129   2.591973e-01
# 10                        addr_state:NY      0.055811   2.114855e-02
# 11         addr_state:OK_TN_MO_LA_MD_NC      0.058078   1.208244e-02
# 12                        addr_state:CA      0.063684   2.638844e-03
# 13               addr_state:UT_KY_AZ_NJ      0.077486   1.859062e-03
# 14            addr_state:AR_MI_PA_OH_MN      0.135918   1.528681e-09
# 15            addr_state:RI_MA_DE_SD_IN      0.098396   9.708572e-04
# 16                  addr_state:GA_WA_OR      0.184778   4.164106e-12
# 17                     addr_state:WI_MT      0.240971   4.050801e-07
# 18                        addr_state:TX      0.222359   1.091064e-17
# 19                     addr_state:IL_CT      0.262112   2.704540e-19
# 20         addr_state:KS_SC_CO_VT_AK_MS      0.319517   3.566714e-25
# 21         addr_state:WV_NH_WY_DC_ME_ID      0.520767   1.228344e-22
# 22     verification_status:Not Verified      0.081427   2.329750e-08
# 23  verification_status:Source Verified     -0.011579   3.886519e-01
# 24                  purpose:credit_card      0.301387   1.284200e-26
# 25           purpose:debt_consolidation      0.197625   2.637140e-14
# 26           purpose:oth__med__vacation      0.214027   5.503210e-12
# 27  purpose:major_purch__car__home_impr      0.266356   1.266217e-17
# 28                initial_list_status:w      0.053978   3.554038e-05
# 29                              term:36      0.076315   4.758063e-08
# 30                         emp_length:1      0.099682   1.204829e-04
# 31                       emp_length:2-4      0.127556   1.331227e-11
# 32                       emp_length:5-6      0.092862   1.412865e-05
# 33                       emp_length:7-9      0.062904   2.478103e-03
# 34                        emp_length:10      0.126634   6.299789e-12
# 35               mths_since_issue_d:<38      1.107287  7.602184e-195
# 36             mths_since_issue_d:38-39      0.903033  5.112844e-164
# 37             mths_since_issue_d:40-41      0.802033  2.035160e-136
# 38             mths_since_issue_d:42-48      0.599287   2.491114e-98
# 39             mths_since_issue_d:49-52      0.437741   1.328019e-46
# 40             mths_since_issue_d:53-64      0.191999   2.048285e-11
# 41             mths_since_issue_d:65-84     -0.047691   9.562579e-02
# 42                      int_rate:<9.548      0.856269   1.575079e-29
# 43                int_rate:9.548-12.025      0.539345   1.082003e-33
# 44                int_rate:12.025-15.74      0.292076   1.678527e-15
# 45                int_rate:15.74-20.281      0.105070   2.850057e-04
# 46  mths_since_earliest_cr_line:141-164      0.054506   2.838658e-02
# 47  mths_since_earliest_cr_line:165-247      0.034867   8.232645e-02
# 48  mths_since_earliest_cr_line:248-270      0.076319   3.613339e-03
# 49  mths_since_earliest_cr_line:271-352      0.118728   3.940241e-07
# 50     mths_since_earliest_cr_line:>352      0.126178   1.923700e-06
# 51                     inq_last_6mths:0      0.728722   2.223384e-22
# 52                   inq_last_6mths:1-2      0.582295   6.967938e-15
# 53                   inq_last_6mths:3-6      0.371090   9.069888e-07
# 54                   acc_now_delinq:>=1      0.080475   3.884121e-01
# 55                   annual_inc:20K-30K     -0.076128   6.855157e-02
# 56                   annual_inc:30K-40K     -0.012542   7.547383e-01
# 57                   annual_inc:40K-50K      0.082088   4.059264e-02
# 58                   annual_inc:50K-60K      0.149117   2.414635e-04
# 59                   annual_inc:60K-70K      0.223690   7.386268e-08
# 60                   annual_inc:70K-80K      0.297728   2.210631e-12
# 61                   annual_inc:80K-90K      0.373366   2.937803e-17
# 62                  annual_inc:90K-100K      0.392945   9.165863e-18
# 63                 annual_inc:100K-120K      0.471332   2.945259e-25
# 64                 annual_inc:120K-140K      0.563563   1.108760e-27
# 65                     annual_inc:>140K      0.497117   7.830288e-26
# 66                            dti:<=1.4      0.248337   2.664019e-03
# 67                          dti:1.4-3.5      0.367862   1.016598e-07
# 68                          dti:3.5-7.7      0.387017   6.348392e-11
# 69                         dti:7.7-10.5      0.322818   4.101930e-08
# 70                        dti:10.5-16.1      0.243819   1.762417e-05
# 71                        dti:16.1-20.3      0.142635   1.216815e-02
# 72                        dti:20.3-21.7      0.130564   2.855677e-02
# 73                        dti:21.7-22.4      0.095873   1.329041e-01
# 74                          dti:22.4-35      0.053202   3.440317e-01
# 75          mths_since_last_delinq:4-30      0.029882   3.596412e-02
# 76         mths_since_last_delinq:31-56      0.076022   3.153367e-06
# 77          mths_since_last_delinq:>=57      0.028950   1.466956e-01
# 78          mths_since_last_record:3-20      0.117086   2.033442e-01
# 79         mths_since_last_record:21-31      0.035485   6.489824e-01
# 80         mths_since_last_record:32-80      0.186250   4.907792e-13
# 81         mths_since_last_record:81-86     -0.148505   1.724220e-02
# 82           mths_since_last_record:>86     -0.084752   1.948360e-04

# %%
import pickle

# %%
pickle.dump(reg2, open('pd_model.sav', 'wb'))
# Here we export our model to a 'SAV' file with file name 'pd_model.sav'.

# %%
model = pickle.load(open('pd_model.sav', 'rb'))
